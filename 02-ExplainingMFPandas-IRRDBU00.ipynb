# %%
# Import the class
from mfpandas import IRRDBU00

# %%
# Let's load and parse our ZPDT unload
r = IRRDBU00(irrdbu00='test_irrdbu00_data')
r.parse_fancycli()
# Out:
# 26-02-19 15:17:24 - parsing test_irrdbu00_data
# 26-02-19 15:17:25 - progress: ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ (100.00%)
# 26-02-19 15:17:25 - recordtype 0100 -> 62 records parsed
# 26-02-19 15:17:25 - recordtype 0120 -> 46 records parsed
# 26-02-19 15:17:25 - recordtype 0102 -> 141 records parsed
# 26-02-19 15:17:25 - recordtype 0101 -> 61 records parsed
# 26-02-19 15:17:25 - recordtype 0207 -> 62 records parsed
# 26-02-19 15:17:25 - recordtype 0200 -> 100 records parsed
# 26-02-19 15:17:25 - recordtype 0203 -> 141 records parsed
# 26-02-19 15:17:25 - recordtype 0205 -> 141 records parsed
# 26-02-19 15:17:25 - recordtype 0220 -> 38 records parsed
# 26-02-19 15:17:25 - recordtype 0270 -> 65 records parsed
# 26-02-19 15:17:25 - recordtype 0251 -> 1 records parsed
# 26-02-19 15:17:25 - recordtype 0250 -> 3 records parsed
# 26-02-19 15:17:25 - recordtype 0202 -> 1 records parsed
# 26-02-19 15:17:25 - recordtype 0403 -> 2 records parsed
# 26-02-19 15:17:25 - recordtype 0404 -> 37 records parsed
# 26-02-19 15:17:25 - recordtype 0400 -> 38 records parsed
# 26-02-19 15:17:25 - recordtype 0505 -> 1825 records parsed
# 26-02-19 15:17:25 - recordtype 0500 -> 888 records parsed
# 26-02-19 15:17:25 - recordtype 1560 -> 62 records parsed
# 26-02-19 15:17:25 - recordtype 0561 -> 100 records parsed
# 26-02-19 15:17:25 - recordtype 0560 -> 82 records parsed
# 26-02-19 15:17:25 - recordtype 0562 -> 100 records parsed
# 26-02-19 15:17:25 - recordtype 0507 -> 1 records parsed
# 26-02-19 15:17:25 - recordtype 0503 -> 67 records parsed
# 26-02-19 15:17:25 - recordtype 0530 -> 7 records parsed
# 26-02-19 15:17:25 - recordtype 05B0 -> 17 records parsed
# 26-02-19 15:17:25 - recordtype 0540 -> 121 records parsed
# 26-02-19 15:17:25 - total parse time: 0.057016 seconds
# 26-02-19 15:17:25 - 0 input lines could not be parsed

# %%
# Now the 'entire' RACF for my zPDT is available in MFPandas / IRRDBU00 Class
# see the https://mfpandas.readthedocs.io for all methods etc.

# Let's get all our special users
r.specials
# Out:
#    USBD_RECORD_TYPE USBD_NAME USBD_CREATE_DATE USBD_OWNER_ID USBD_ADSP  \
# 16             0200   ADCDMST       2004-11-10          SYS1        NO
# 44             0200   IBMUSER       1995-06-06       IBMUSER        NO
# 66             0200    SYSOPR       1997-12-22       IBMUSER        NO
# 69             0200     USER1       2020-08-27       IBMUSER        NO
# 70             0200     USER2       2020-08-27       IBMUSER        NO
# 71             0200     USER3       2020-08-27       IBMUSER        NO
#
#    USBD_SPECIAL USBD_OPER USBD_REVOKE USBD_GRPACC USBD_PWD_INTERVAL  ...  \
# 16          YES       YES          NO          NO               180  ...
# 44          YES       YES          NO          NO               000  ...
# 66          YES        NO          NO         YES               180  ...
# 69          YES       YES          NO          NO               180  ...
# 70          YES       YES          NO          NO               180  ...
# 71          YES       YES          NO          NO               180  ...
#
#    USBD_PPHENV_EXISTS USBD_PWD_ALG USBD_LEG_PWDHIST_CT USBD_XPW_PWDHIST_CT  \
# 16                 NO       KDFAES                 000                 000
# 44                 NO       KDFAES                 000                 000
# 66                 NO       KDFAES                 000                 000
# 69                 NO       KDFAES                 000                 000
# 70                 NO       KDFAES                 000                 000
# 71                 NO       KDFAES                 000                 000
#
#    USBD_PHR_ALG USBD_LEG_PHRHIST_CT USBD_XPW_PHRHIST_CT USBD_ROAUDIT  \
# 16     NOPHRASE                 000                 000           NO
# 44     NOPHRASE                 000                 000           NO
# 66     NOPHRASE                 000                 000           NO
# 69     NOPHRASE                 000                 000           NO
# 70     NOPHRASE                 000                 000           NO
# 71     NOPHRASE                 000                 000           NO
#
#    USBD_MFA_FALLBACK USBD_PHR_INTERVAL
# 16                NO
# 44                NO
# 66                NO
# 69                NO
# 70                NO
# 71                NO
#
# [6 rows x 52 columns]

# %%
# What about all our users?
r.users[['USBD_NAME','USBD_SPECIAL']]
# Out:
#    USBD_NAME USBD_SPECIAL
# 0   irrcerta           NO
# 1   irrmulti           NO
# 2   irrsitec           NO
# 3      ADCDA           NO
# 4      ADCDB           NO
# ..       ...          ...
# 95   ZOSCSRV           NO
# 96   ZOSMFAD           NO
# 97   ZOSUGST           NO
# 98  ZWESIUSR           NO
# 99  ZWESVUSR           NO
#
# [100 rows x 2 columns]

# %%
# Can we see the groups too?
r.groups
# Out:
#    GPBD_RECORD_TYPE GPBD_NAME GPBD_SUPGRP_ID GPBD_CREATE_DATE GPBD_OWNER_ID  \
# 0              0100      ADCD           SYS1       2012-11-30       IBMUSER
# 1              0100    BLZCFG           SYS1       2014-08-07       ADCDMST
# 2              0100    BLZGRP           SYS1       2014-08-07       IBMUSER
# 3              0100    BLZWRK           SYS1       2014-08-07       ADCDMST
# 4              0100     CEAGP           SYS1       2009-11-17       IBMUSER
# ..              ...       ...            ...              ...           ...
# 57             0100       ZDO           SYS1       2021-05-07       IBMUSER
# 58             0100   ZOSCGRP           SYS1       2016-03-22          SYS1
# 59             0100   ZOSUGRP           SYS1       2016-03-22          SYS1
# 60             0100  ZWEADMIN           SYS1       2020-05-06       IBMUSER
# 61             0100    ZWE100           SYS1       2020-05-06       IBMUSER
#
#    GPBD_UACC GPBD_NOTERMUACC  \
# 0       NONE              NO
# 1       NONE              NO
# 2       NONE              NO
# 3       NONE              NO
# 4       NONE              NO
# ..       ...             ...
# 57      NONE              NO
# 58      NONE              NO
# 59      NONE              NO
# 60      NONE              NO
# 61      NONE              NO
#
#                                     GPBD_INSTALL_DATA GPBD_MODEL  \
# 0
# 1   GROUP WITH OMVS SEGMENT FOR JAZZ CONFIG DIRECT...
# 2                    RATIONAL TEAM CONCERT - HLQ STUB
# 3   GROUP WITH OMVS SEGMENT FOR JAZZ WORK DIRECTORIES
# 4
# ..                                                ...        ...
# 57                                      ZDO HLQ GROUP
# 58                                ZOSCONN LIBERTY GRP
# 59                               ZOSCONN UNAUTH GROUP
# 60                                   ZOWE ADMIN GROUP
# 61                                    ZOWE - HLQ STUB
#
#    GPBD_UNIVERSAL
# 0              NO
# 1              NO
# 2              NO
# 3              NO
# 4              NO
# ..            ...
# 57             NO
# 58             NO
# 59             NO
# 60             NO
# 61             NO
#
# [62 rows x 10 columns]

# %%
# Dataset profiles?
r.datasets
# Out:
#    DSBD_RECORD_TYPE             DSBD_NAME DSBD_VOL DSBD_GENERIC  \
# 0              0400    ADCD.S0W1.HZSPDATA   HDRES1           NO
# 1              0400            ADCDA.*.**                   YES
# 2              0400            ADCDB.*.**                   YES
# 3              0400            ADCDC.*.**                   YES
# 4              0400            ADCDD.*.**                   YES
# 5              0400            ADCDE.*.**                   YES
# 6              0400            ADCDF.*.**                   YES
# 7              0400            ADCDG.*.**                   YES
# 8              0400            ADCDH.*.**                   YES
# 9              0400            ADCDI.*.**                   YES
# 10             0400            ADCDJ.*.**                   YES
# 11             0400            ADCDK.*.**                   YES
# 12             0400            ADCDL.*.**                   YES
# 13             0400            ADCDM.*.**                   YES
# 14             0400          ADCDMST.*.**                   YES
# 15             0400            ADCDN.*.**                   YES
# 16             0400            ADCDO.*.**                   YES
# 17             0400            ADCDP.*.**                   YES
# 18             0400            ADCDQ.*.**                   YES
# 19             0400            ADCDR.*.**                   YES
# 20             0400            ADCDS.*.**                   YES
# 21             0400            ADCDT.*.**                   YES
# 22             0400            ADCDU.*.**                   YES
# 23             0400            ADCDV.*.**                   YES
# 24             0400            ADCDW.*.**                   YES
# 25             0400            ADCDX.*.**                   YES
# 26             0400            ADCDY.*.**                   YES
# 27             0400            ADCDZ.*.**                   YES
# 28             0400              CEA.*.**                   YES
# 29             0400  IBMUSER.IBMUSER.*.**                   YES
# 30             0400             TEST.*.**                   YES
# 31             0400           USERCAT.ZDO   B4USR1           NO
# 32             0400            USER1.*.**                   YES
# 33             0400            USER2.*.**                   YES
# 34             0400            USER3.*.**                   YES
# 35             0400         ZDO.PRJ.*.ZFS                   YES
# 36             0400             ZDO.*.ZFS                   YES
# 37             0400              ZDO.*.**                   YES
#
#    DSBD_CREATE_DATE DSBD_OWNER_ID DSBD_LASTREF_DATE DSBD_LASTCHG_DATE  \
# 0        2012-11-30       IBMUSER        2012-11-30        2012-11-30
# 1        2007-06-01         ADCDA        2007-06-01        2007-06-01
# 2        2007-06-01         ADCDB        2007-06-01        2007-06-01
# 3        2007-06-01         ADCDC        2007-06-01        2007-06-01
# 4        2007-06-01         ADCDD        2007-06-01        2007-06-01
# 5        2007-06-01         ADCDE        2007-06-01        2007-06-01
# 6        2007-06-01         ADCDF        2007-06-01        2007-06-01
# 7        2007-06-01         ADCDG        2007-06-01        2007-06-01
# 8        2007-06-01         ADCDH        2007-06-01        2007-06-01
# 9        2007-06-01         ADCDI        2007-06-01        2007-06-01
# 10       2007-06-01         ADCDJ        2007-06-01        2007-06-01
# 11       2007-06-01         ADCDK        2007-06-01        2007-06-01
# 12       2007-06-01         ADCDL        2007-06-01        2007-06-01
# 13       2007-06-01         ADCDM        2007-06-01        2007-06-01
# 14       2004-11-10       ADCDMST        2004-11-10        2004-11-10
# 15       2007-06-01         ADCDN        2007-06-01        2007-06-01
# 16       2007-06-01         ADCDO        2007-06-01        2007-06-01
# 17       2007-06-01         ADCDP        2007-06-01        2007-06-01
# 18       2007-06-01         ADCDQ        2007-06-01        2007-06-01
# 19       2007-06-01         ADCDR        2007-06-01        2007-06-01
# 20       2007-06-01         ADCDS        2007-06-01        2007-06-01
# 21       2007-06-01         ADCDT        2007-06-01        2007-06-01
# 22       2007-06-01         ADCDU        2007-06-01        2007-06-01
# 23       2007-06-01         ADCDV        2007-06-01        2007-06-01
# 24       2007-06-01         ADCDW        2007-06-01        2007-06-01
# 25       2007-06-01         ADCDX        2007-06-01        2007-06-01
# 26       2007-06-01         ADCDY        2007-06-01        2007-06-01
# 27       2007-06-01         ADCDZ        2007-06-01        2007-06-01
# 28       2012-12-03           CEA        2012-12-03        2012-12-03
# 29       2006-05-04       IBMUSER        2006-05-04        2006-05-04
# 30       2021-05-25       IBMUSER        2021-05-25        2021-05-25
# 31       2021-05-07       IBMUSER        2021-05-07        2021-05-07
# 32       2020-08-27         USER1        2020-08-27        2020-08-27
# 33       2020-08-27         USER2        2020-08-27        2020-08-27
# 34       2020-08-27         USER3        2020-08-27        2020-08-27
# 35       2021-05-12       IBMUSER        2021-05-12        2021-05-12
# 36       2021-05-07       IBMUSER        2021-05-07        2021-05-07
# 37       2021-05-07       IBMUSER        2021-05-07        2021-05-07
#
#    DSBD_ALTER_CNT DSBD_CONTROL_CNT  ... DSBD_GAUDIT_OKQUAL DSBD_GAUDIT_FAQUAL  \
# 0           00000            00000  ...
# 1           00000            00000  ...
# 2           00000            00000  ...
# 3           00000            00000  ...
# 4           00000            00000  ...
# 5           00000            00000  ...
# 6           00000            00000  ...
# 7           00000            00000  ...
# 8           00000            00000  ...
# 9           00000            00000  ...
# 10          00000            00000  ...
# 11          00000            00000  ...
# 12          00000            00000  ...
# 13          00000            00000  ...
# 14          00000            00000  ...
# 15          00000            00000  ...
# 16          00000            00000  ...
# 17          00000            00000  ...
# 18          00000            00000  ...
# 19          00000            00000  ...
# 20          00000            00000  ...
# 21          00000            00000  ...
# 22          00000            00000  ...
# 23          00000            00000  ...
# 24          00000            00000  ...
# 25          00000            00000  ...
# 26          00000            00000  ...
# 27          00000            00000  ...
# 28          00000            00000  ...
# 29          00000            00000  ...
# 30          00000            00000  ...
# 31          00000            00000  ...
# 32          00000            00000  ...
# 33          00000            00000  ...
# 34          00000            00000  ...
# 35          00000            00000  ...
# 36          00000            00000  ...
# 37          00000            00000  ...
#
#    DSBD_WARNING DSBD_SECLEVEL DSBD_NOTIFY_ID DSBD_RETENTION DSBD_ERASE  \
# 0            NO           000                         00000         NO
# 1            NO           000                         00000         NO
# 2            NO           000                         00000         NO
# 3            NO           000                         00000         NO
# 4            NO           000                         00000         NO
# 5            NO           000                         00000         NO
# 6            NO           000                         00000         NO
# 7            NO           000                         00000         NO
# 8            NO           000                         00000         NO
# 9            NO           000                         00000         NO
# 10           NO           000                         00000         NO
# 11           NO           000                         00000         NO
# 12           NO           000                         00000         NO
# 13           NO           000                         00000         NO
# 14           NO           000                         00000         NO
# 15           NO           000                         00000         NO
# 16           NO           000                         00000         NO
# 17           NO           000                         00000         NO
# 18           NO           000                         00000         NO
# 19           NO           000                         00000         NO
# 20           NO           000                         00000         NO
# 21           NO           000                         00000         NO
# 22           NO           000                         00000         NO
# 23           NO           000                         00000         NO
# 24           NO           000                         00000         NO
# 25           NO           000                         00000         NO
# 26           NO           000                         00000         NO
# 27           NO           000                         00000         NO
# 28           NO           000                         00000         NO
# 29           NO           000                         00000         NO
# 30           NO           000                         00000         NO
# 31           NO           000                         00000         NO
# 32           NO           000                         00000         NO
# 33           NO           000                         00000         NO
# 34           NO           000                         00000         NO
# 35           NO           000                         00000         NO
# 36           NO           000                         00000         NO
# 37           NO           000                         00000         NO
#
#    DSBD_SECLABEL DSBD_RESERVED_01 DSBD_RESERVED_02
# 0                            NSET             NSET
# 1                            NSET             NSET
# 2                            NSET             NSET
# 3                            NSET             NSET
# 4                            NSET             NSET
# 5                            NSET             NSET
# 6                            NSET             NSET
# 7                            NSET             NSET
# 8                            NSET             NSET
# 9                            NSET             NSET
# 10                           NSET             NSET
# 11                           NSET             NSET
# 12                           NSET             NSET
# 13                           NSET             NSET
# 14                           NSET             NSET
# 15                           NSET             NSET
# 16                           NSET             NSET
# 17                           NSET             NSET
# 18                           NSET             NSET
# 19                           NSET             NSET
# 20                           NSET             NSET
# 21                           NSET             NSET
# 22                           NSET             NSET
# 23                           NSET             NSET
# 24                           NSET             NSET
# 25                           NSET             NSET
# 26                           NSET             NSET
# 27                           NSET             NSET
# 28                           NSET             NSET
# 29                           NSET             NSET
# 30                           NSET             NSET
# 31                           NSET             NSET
# 32                           NSET             NSET
# 33                           NSET             NSET
# 34                           NSET             NSET
# 35                           NSET             NSET
# 36                           NSET             NSET
# 37                           NSET             NSET
#
# [38 rows x 33 columns]

# %%
# access to those datasets?
r.datasetAccess
# Out:
#    DSACC_RECORD_TYPE          DSACC_NAME DSACC_VOL DSACC_AUTH_ID DSACC_ACCESS  \
# 0               0404  ADCD.S0W1.HZSPDATA    HDRES1        HCUSER         READ
# 1               0404  ADCD.S0W1.HZSPDATA    HDRES1       ADCDMST         READ
# 2               0404          ADCDA.*.**                   ADCDA        ALTER
# 3               0404          ADCDB.*.**                   ADCDB        ALTER
# 4               0404          ADCDC.*.**                   ADCDC        ALTER
# 5               0404          ADCDD.*.**                   ADCDD        ALTER
# 6               0404          ADCDE.*.**                   ADCDE        ALTER
# 7               0404          ADCDF.*.**                   ADCDF        ALTER
# 8               0404          ADCDG.*.**                   ADCDG        ALTER
# 9               0404          ADCDH.*.**                   ADCDH        ALTER
# 10              0404          ADCDI.*.**                   ADCDI        ALTER
# 11              0404          ADCDJ.*.**                   ADCDJ        ALTER
# 12              0404          ADCDK.*.**                   ADCDK        ALTER
# 13              0404          ADCDL.*.**                   ADCDL        ALTER
# 14              0404          ADCDM.*.**                   ADCDM        ALTER
# 15              0404          ADCDN.*.**                   ADCDN        ALTER
# 16              0404          ADCDO.*.**                   ADCDO        ALTER
# 17              0404          ADCDP.*.**                   ADCDP        ALTER
# 18              0404          ADCDQ.*.**                   ADCDQ        ALTER
# 19              0404          ADCDR.*.**                   ADCDR        ALTER
# 20              0404          ADCDS.*.**                   ADCDS        ALTER
# 21              0404          ADCDT.*.**                   ADCDT        ALTER
# 22              0404          ADCDU.*.**                   ADCDU        ALTER
# 23              0404          ADCDV.*.**                   ADCDV        ALTER
# 24              0404          ADCDW.*.**                   ADCDW        ALTER
# 25              0404          ADCDX.*.**                   ADCDX        ALTER
# 26              0404          ADCDY.*.**                   ADCDY        ALTER
# 27              0404          ADCDZ.*.**                   ADCDZ        ALTER
# 28              0404            CEA.*.**                CFZUSRGP        ALTER
# 29              0404            CEA.*.**                CFZADMGP        ALTER
# 30              0404            CEA.*.**                IZUADMIN        ALTER
# 31              0404            CEA.*.**                 IZUUSER        ALTER
# 32              0404         USERCAT.ZDO    B4USR1             *       UPDATE
# 33              0404          USER1.*.**                   USER1        ALTER
# 34              0404          USER2.*.**                   USER2        ALTER
# 35              0404          USER3.*.**                   USER3        ALTER
# 36              0404            ZDO.*.**                       *         READ
#
#    DSACC_ACCESS_CNT
# 0             00000
# 1             00000
# 2             00000
# 3             00000
# 4             00000
# 5             00000
# 6             00000
# 7             00000
# 8             00000
# 9             00000
# 10            00000
# 11            00000
# 12            00000
# 13            00000
# 14            00000
# 15            00000
# 16            00000
# 17            00000
# 18            00000
# 19            00000
# 20            00000
# 21            00000
# 22            00000
# 23            00000
# 24            00000
# 25            00000
# 26            00000
# 27            00000
# 28            00000
# 29            00000
# 30            00000
# 31            00000
# 32            00000
# 33            00000
# 34            00000
# 35            00000
# 36            00000

# %%
# Show me the acceslist of the usercatalog
r.datasetAccess.loc[r.datasetAccess.DSACC_NAME=='USERCAT.ZDO']
# Out:
#    DSACC_RECORD_TYPE   DSACC_NAME DSACC_VOL DSACC_AUTH_ID DSACC_ACCESS  \
# 32              0404  USERCAT.ZDO    B4USR1             *       UPDATE
#
#    DSACC_ACCESS_CNT
# 32            00000

# %%
# oooh... so there's a lot of ID(*) on the accesslist? Let's see
r.datasetAccess.loc[r.datasetAccess.DSACC_AUTH_ID=='*']
# Out:
#    DSACC_RECORD_TYPE   DSACC_NAME DSACC_VOL DSACC_AUTH_ID DSACC_ACCESS  \
# 32              0404  USERCAT.ZDO    B4USR1             *       UPDATE
# 36              0404     ZDO.*.**                       *         READ
#
#    DSACC_ACCESS_CNT
# 32            00000
# 36            00000

# %%
# oooh not too much then....... do we have the bad stuff?
r.datasets.loc[r.datasets.DSBD_UACC=='READ']
# Out:
#    DSBD_RECORD_TYPE             DSBD_NAME DSBD_VOL DSBD_GENERIC  \
# 14             0400          ADCDMST.*.**                   YES
# 29             0400  IBMUSER.IBMUSER.*.**                   YES
# 35             0400         ZDO.PRJ.*.ZFS                   YES
# 36             0400             ZDO.*.ZFS                   YES
#
#    DSBD_CREATE_DATE DSBD_OWNER_ID DSBD_LASTREF_DATE DSBD_LASTCHG_DATE  \
# 14       2004-11-10       ADCDMST        2004-11-10        2004-11-10
# 29       2006-05-04       IBMUSER        2006-05-04        2006-05-04
# 35       2021-05-12       IBMUSER        2021-05-12        2021-05-12
# 36       2021-05-07       IBMUSER        2021-05-07        2021-05-07
#
#    DSBD_ALTER_CNT DSBD_CONTROL_CNT  ... DSBD_GAUDIT_OKQUAL DSBD_GAUDIT_FAQUAL  \
# 14          00000            00000  ...
# 29          00000            00000  ...
# 35          00000            00000  ...
# 36          00000            00000  ...
#
#    DSBD_WARNING DSBD_SECLEVEL DSBD_NOTIFY_ID DSBD_RETENTION DSBD_ERASE  \
# 14           NO           000                         00000         NO
# 29           NO           000                         00000         NO
# 35           NO           000                         00000         NO
# 36           NO           000                         00000         NO
#
#    DSBD_SECLABEL DSBD_RESERVED_01 DSBD_RESERVED_02
# 14                           NSET             NSET
# 29                           NSET             NSET
# 35                           NSET             NSET
# 36                           NSET             NSET
#
# [4 rows x 33 columns]

# %%
# How is our KDFAES going?
r.users.loc[r.users.USBD_PWD_ALG=='LEGACY'][['USBD_NAME','USBD_PWD_ALG']]
# Out:
#    USBD_NAME USBD_PWD_ALG
# 4      ADCDB       LEGACY
# 5      ADCDC       LEGACY
# 6      ADCDD       LEGACY
# 7      ADCDE       LEGACY
# 8      ADCDF       LEGACY
# 9      ADCDG       LEGACY
# 10     ADCDH       LEGACY
# 11     ADCDI       LEGACY
# 12     ADCDJ       LEGACY
# 13     ADCDK       LEGACY
# 14     ADCDL       LEGACY
# 15     ADCDM       LEGACY
# 17     ADCDN       LEGACY
# 18     ADCDO       LEGACY
# 19     ADCDP       LEGACY
# 20     ADCDQ       LEGACY
# 21     ADCDR       LEGACY
# 22     ADCDS       LEGACY
# 23     ADCDT       LEGACY
# 24     ADCDU       LEGACY
# 25     ADCDV       LEGACY
# 26     ADCDW       LEGACY
# 27     ADCDX       LEGACY
# 28     ADCDY       LEGACY
# 29     ADCDZ       LEGACY
# 30  BPXOINIT       LEGACY
# 31       CEA       LEGACY
# 34  DB8GRFSH       LEGACY
# 35  DB9GENV5       LEGACY
# 36  DB9GRFSH       LEGACY
# 37  DSN1WLM1       LEGACY
# 39      FTPD       LEGACY
# 45     INETD       LEGACY
# 46  INTERNAL       LEGACY
# 50  OMVSKERN       LEGACY
# 51     OPEN1       LEGACY
# 52     OPEN2       LEGACY
# 53     OPEN3       LEGACY
# 54   PRIVATE       LEGACY
# 55    PUBLIC       LEGACY
# 67     TCPIP       LEGACY
# 73    WEBADM       LEGACY
# 74    WEBSRV       LEGACY
# 91   XSADMIN       LEGACY
# 96   ZOSMFAD       LEGACY

# %%
# A recent feature, what would happen if we 
r.whatif(userid='IBMUSER',without_groups=['SYS1'])
# Out:
#      profileclass                                            profile current  \
# 0         DATASET                                           CEA.*.**   ALTER
# 1         DATASET                                           CEA.*.**   ALTER
# 2         ACCTNUM                                              ACCT#    READ
# 3         ACCTNUM                                              ACCT#    READ
# 4         ACCTNUM                                              ACCT#    READ
# ...           ...                                                ...     ...
# 1052     ZMFCLOUD  IZUDFLT.ZOSMF.TEMPLATE.RUNASUSERS.IYU0.ADCD-CI...    READ
# 1053     ZMFCLOUD  IZUDFLT.ZOSMF.TEMPLATE.RUNASUSERS.IYU0.ADCD-MQ911    READ
# 1054     ZMFCLOUD    IZUDFLT.ZOSMF.TEMPLATE.RUNASUSERS.IYU0.ADCD-WLP    READ
# 1055     ZMFCLOUD  IZUDFLT.ZOSMF.TEMPLATE.RUNASUSERS.IYU0.ADCD-ZO...    READ
# 1056     ZMFCLOUD      IZUDFLT.ZOSMF.TEMPLATE.RUNASUSERS.IYU0.CICS55    READ
#
#      whatif
# 0     ALTER
# 1     ALTER
# 2      READ
# 3      READ
# 4      READ
# ...     ...
# 1052   READ
# 1053   READ
# 1054   READ
# 1055   READ
# 1056   READ
#
# [1057 rows x 4 columns]

# %%
# Let's condense that to just what this user looses.
r.lostaccess('IBMUSER', without_groups=['SYS1'])
# Out:
#     profileclass                  profile   lost
# 547       SERVER        DB2.DBAG.DBAGENVC  ALTER
# 548       SERVER        DB2.DBAG.DBAGENVD  ALTER
# 549       SERVER        DB2.DBAG.DBAGENVG  ALTER
# 550       SERVER        DB2.DBAG.DBAGENVJ  ALTER
# 551       SERVER        DB2.DBAG.DBAGENVM  ALTER
# 552       SERVER        DB2.DBAG.DBAGENVO  ALTER
# 553       SERVER        DB2.DBAG.DBAGENVP  ALTER
# 554       SERVER        DB2.DBAG.DBAGENVR  ALTER
# 555       SERVER        DB2.DBAG.DBAGENVU  ALTER
# 556       SERVER        DB2.DBAG.DBAGENVW  ALTER
# 557       SERVER        DB2.DBAG.DBAGENVX  ALTER
# 558       SERVER        DB2.DBAG.DBAGENV1  ALTER
# 559       SERVER        DB2.DBAG.DBAGRFSH  ALTER
# 853     UNIXPRIV        SUPERUSER.FILESYS   READ
# 854     UNIXPRIV  SUPERUSER.FILESYS.CHOWN   READ
# 857     XFACILIT                   HZS.**   READ

# %%
# Let's go crazy
r.xls(fileName='Demo.xlsx')
